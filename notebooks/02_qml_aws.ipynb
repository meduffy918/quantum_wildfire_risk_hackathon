# %% [markdown]
# Load Python libraries

# %%
import pandas as pd

import sys
# !{sys.executable} -m pip install scikit-learn pandas matplotlib pennylane amazon-braket-pennylane-plugin
# Out:
# Requirement already satisfied: scikit-learn in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (1.8.0)
# Requirement already satisfied: pandas in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (2.3.3)
# Requirement already satisfied: matplotlib in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (3.10.8)
# Requirement already satisfied: pennylane in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (0.44.1)
# Requirement already satisfied: amazon-braket-pennylane-plugin in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (1.34.0)
# Requirement already satisfied: numpy>=1.24.1 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from scikit-learn) (2.2.6)
# Requirement already satisfied: scipy>=1.10.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from pandas) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from pandas) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: networkx in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from pennylane) (3.6.1)
# Requirement already satisfied: rustworkx>=0.14.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from pennylane) (0.17.1)
# Requirement already satisfied: autograd in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from pennylane) (1.8.0)
# Requirement already satisfied: appdirs in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from pennylane) (1.4.4)
# Requirement already satisfied: autoray==0.8.2 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from pennylane) (0.8.2)
# Requirement already satisfied: cachetools in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from pennylane) (7.0.5)
# Requirement already satisfied: pennylane-lightning>=0.44 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from pennylane) (0.44.0)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from pennylane) (2.32.5)
# Requirement already satisfied: tomlkit in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from pennylane) (0.14.0)
# Requirement already satisfied: typing_extensions in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from pennylane) (4.15.0)
# Requirement already satisfied: diastatic-malt==2.15.2 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from pennylane) (2.15.2)
# Requirement already satisfied: gast in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from pennylane) (0.7.0)
# Requirement already satisfied: astunparse in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from diastatic-malt==2.15.2->pennylane) (1.6.3)
# Requirement already satisfied: termcolor in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from diastatic-malt==2.15.2->pennylane) (3.3.0)
# Requirement already satisfied: amazon-braket-sdk>=1.97.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from amazon-braket-pennylane-plugin) (1.113.1)
# Requirement already satisfied: amazon-braket-schemas>=1.27.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from amazon-braket-sdk>=1.97.0->amazon-braket-pennylane-plugin) (1.29.0)
# Requirement already satisfied: amazon-braket-default-simulator>=1.32.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from amazon-braket-sdk>=1.97.0->amazon-braket-pennylane-plugin) (1.34.1)
# Requirement already satisfied: oqpy~=0.3.7 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from amazon-braket-sdk>=1.97.0->amazon-braket-pennylane-plugin) (0.3.10)
# Requirement already satisfied: backoff in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from amazon-braket-sdk>=1.97.0->amazon-braket-pennylane-plugin) (2.2.1)
# Requirement already satisfied: boltons in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from amazon-braket-sdk>=1.97.0->amazon-braket-pennylane-plugin) (25.0.0)
# Requirement already satisfied: boto3>=1.28.53 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from amazon-braket-sdk>=1.97.0->amazon-braket-pennylane-plugin) (1.42.70)
# Requirement already satisfied: cloudpickle==2.2.1 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from amazon-braket-sdk>=1.97.0->amazon-braket-pennylane-plugin) (2.2.1)
# Requirement already satisfied: nest-asyncio in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from amazon-braket-sdk>=1.97.0->amazon-braket-pennylane-plugin) (1.6.0)
# Requirement already satisfied: openpulse in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from amazon-braket-sdk>=1.97.0->amazon-braket-pennylane-plugin) (1.0.1)
# Requirement already satisfied: openqasm3 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from amazon-braket-sdk>=1.97.0->amazon-braket-pennylane-plugin) (1.0.1)
# Requirement already satisfied: sympy in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from amazon-braket-sdk>=1.97.0->amazon-braket-pennylane-plugin) (1.12.1)
# Requirement already satisfied: backports.entry-points-selectable in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from amazon-braket-sdk>=1.97.0->amazon-braket-pennylane-plugin) (1.3.0)
# Requirement already satisfied: mypy-extensions>=0.2.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from oqpy~=0.3.7->amazon-braket-sdk>=1.97.0->amazon-braket-pennylane-plugin) (1.1.0)
# Requirement already satisfied: numba in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk>=1.97.0->amazon-braket-pennylane-plugin) (0.64.0)
# Requirement already satisfied: opt_einsum in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk>=1.97.0->amazon-braket-pennylane-plugin) (3.4.0)
# Requirement already satisfied: pydantic>2 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk>=1.97.0->amazon-braket-pennylane-plugin) (2.12.5)
# Requirement already satisfied: setuptools==81.0.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk>=1.97.0->amazon-braket-pennylane-plugin) (81.0.0)
# Requirement already satisfied: antlr4-python3-runtime==4.13.2 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk>=1.97.0->amazon-braket-pennylane-plugin) (4.13.2)
# Requirement already satisfied: botocore<1.43.0,>=1.42.70 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from boto3>=1.28.53->amazon-braket-sdk>=1.97.0->amazon-braket-pennylane-plugin) (1.42.70)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from boto3>=1.28.53->amazon-braket-sdk>=1.97.0->amazon-braket-pennylane-plugin) (0.10.0)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from boto3>=1.28.53->amazon-braket-sdk>=1.97.0->amazon-braket-pennylane-plugin) (0.16.0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from botocore<1.43.0,>=1.42.70->boto3>=1.28.53->amazon-braket-sdk>=1.97.0->amazon-braket-pennylane-plugin) (2.6.3)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: scipy-openblas32>=0.3.26 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from pennylane-lightning>=0.44->pennylane) (0.3.31.159.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from pydantic>2->amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk>=1.97.0->amazon-braket-pennylane-plugin) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from pydantic>2->amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk>=1.97.0->amazon-braket-pennylane-plugin) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from pydantic>2->amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk>=1.97.0->amazon-braket-pennylane-plugin) (0.4.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from astunparse->diastatic-malt==2.15.2->pennylane) (0.46.3)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from numba->amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk>=1.97.0->amazon-braket-pennylane-plugin) (0.46.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from requests->pennylane) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from requests->pennylane) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from requests->pennylane) (2026.2.25)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /home/ec2-user/anaconda3/envs/Braket/lib/python3.12/site-packages (from sympy->amazon-braket-sdk>=1.97.0->amazon-braket-pennylane-plugin) (1.3.0)

# %% [markdown]
# Loads cleaned data in QML notebook

# %%
df = pd.read_csv("../data/cleaned_wildfire_data.csv")
df.head()
# Out:
#    avg_tmax_c  avg_tmin_c  tot_prcp_mm  month  temp_range  hot_dry  zip3_890  \
# 0         NaN         NaN          NaN    7.0         NaN      NaN     False
# 1         NaN         NaN          NaN   12.0         NaN      NaN     False
# 2         NaN         NaN          NaN   12.0         NaN      NaN     False
# 3   21.748387   11.432258         35.5    1.0   10.316129  0.61091     False
# 4   21.748387   11.432258         35.5    1.0   10.316129  0.61091     False
#
#    zip3_894  zip3_895  zip3_900  ...  zip3_959  zip3_960  zip3_961  zip3_975  \
# 0     False     False     False  ...     False     False     False     False
# 1     False     False     False  ...     False     False     False     False
# 2     False     False     False  ...     False     False     False     False
# 3     False     False      True  ...     False     False     False     False
# 4     False     False      True  ...     False     False     False     False
#
#    zip3_976  risk  Year      zip  risk_score  predicted_risk
# 0     False     0  2019  95470.0         NaN             NaN
# 1     False     0  2018  93060.0         NaN             NaN
# 2     False     0  2018  93066.0         NaN             NaN
# 3     False     0  2018  90001.0         NaN             NaN
# 4     False     0  2018  90002.0         NaN             NaN
#
# [5 rows x 76 columns]

# %% [markdown]
# Selects quantum features (only uses 4 due to hardware limitations)

# %%
id_cols = ['zip', 'Year']
q_features = ['avg_tmax_c', 'tot_prcp_mm', 'month', 'hot_dry']
target = 'risk'

train_df = df[df['Year'] < 2023].copy()
test_df = df[df['Year'] == 2023].copy()

Xq_train = train_df[q_features]
yq_train = train_df[target].values

Xq_test = test_df[q_features]
yq_test = test_df[target].values

# %% [markdown]
# Fills empty NaN values with median of each column

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='median')

Xq_train_imputed = imputer.fit_transform(Xq_train)
Xq_test_imputed = imputer.transform(Xq_test)

# %% [markdown]
# Preprocessing for angle encoding on bounded angle range [-pi, pi]

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np

scaler = MinMaxScaler(feature_range=(-np.pi, np.pi))

Xq_train_angles = scaler.fit_transform(Xq_train_imputed)
Xq_test_angles = scaler.transform(Xq_test_imputed)
# Out:
# (array([[ 0.82031762, -3.11075073,  0.28559933, -2.93652035],
#         [ 0.82031762, -3.11075073,  3.14159265, -2.93652035],
#         [ 0.82031762, -3.11075073,  3.14159265, -2.93652035]]),
#  array([[ 0.82031762, -3.11075073, -1.99919533, -2.93652035],
#         [ 0.82031762, -3.11075073, -1.42799666, -2.93652035],
#         [ 0.82031762, -3.11075073, -1.42799666, -2.93652035]]))

# %% [markdown]
# Modifies for a 3:1 ratio (more manageable for QML)

# %%
from sklearn.utils import resample

train_pos_idx = np.where(yq_train == 1)[0]
train_neg_idx = np.where(yq_train == 0)[0]

n_pos_sample = 10
n_neg_sample = 30

# %% [markdown]
# Transforms dataset into manageable subset for training by randomly selecting positive and negative examples and building feature and label arrays

# %%
sampled_pos_idx = resample(train_pos_idx, replace=False, n_samples=n_pos_sample, random_state=42)
sampled_neg_idx = resample(train_neg_idx, replace=False, n_samples=n_neg_sample, random_state=42)

train_idx_small = np.concatenate([sampled_pos_idx, sampled_neg_idx])
np.random.shuffle(train_idx_small)

Xq_train_small = Xq_train_angles[train_idx_small]
Xq_train_small = np.asarray(Xq_train_small, dtype=np.float64)
yq_train_small = yq_train[train_idx_small]
yq_train_small = np.asarray(yq_train_small, dtype=np.float64)
# Out:
# Small train set shape: (40, 4)
# Positive rate: 0.25

# %% [markdown]
# Imports PennyLane and configures training/inference backends

# %%
import pennylane as qml
from pennylane import numpy as pnp

TRAIN_BACKEND = 'local'
INFER_BACKEND = 'sv1'
N_SHOTS = 50

# %% [markdown]
# Defines the circuit by turning it into an optimizable function with angle encoding and entanglement

# %%
n_qubits = 4
n_layers = 2

if TRAIN_BACKEND == 'local':
    train_dev = qml.device('default.qubit', wires=n_qubits)
else:
    raise ValueError("TRAIN_BACKEND must be 'local' for training.")

if INFER_BACKEND == 'local':
    infer_dev = qml.device('default.qubit', wires=n_qubits)

elif INFER_BACKEND == 'sv1':
    infer_dev = qml.device(
        'braket.aws.qubit',
        device_arn='arn:aws:braket:::device/quantum-simulator/amazon/sv1',
        wires=n_qubits,
        shots=N_SHOTS
    )

else:
    raise ValueError("INFER_BACKEND must be 'local' or 'sv1'.")

@qml.qnode(train_dev, interface='autograd')
def train_qnode(x, weights):
    qml.AngleEmbedding(x, wires=range(n_qubits), rotation='Y')
    qml.StronglyEntanglingLayers(weights, wires=range(n_qubits))
    return qml.expval(qml.PauliZ(0))

@qml.qnode(infer_dev, interface='autograd')
def infer_qnode(x, weights):
    qml.AngleEmbedding(x, wires=range(n_qubits), rotation='Y')
    qml.StronglyEntanglingLayers(weights, wires=range(n_qubits))
    return qml.expval(qml.PauliZ(0))
# Out:
# TRAIN_BACKEND = local
# INFER_BACKEND = sv1
# TRAIN_BACKEND = local
# INFER_BACKEND = sv1

# %% [markdown]
# Transforms QNode output to risk score, a scaled expectation value

# %%
def quantum_model_train(x, weights):
    raw = train_qnode(x, weights)
    prob = (raw + 1) / 2
    return prob

def quantum_model_infer(x, weights):
    raw = infer_qnode(x, weights)
    prob = (raw + 1) / 2
    return prob

# %% [markdown]
# Applies a higher loss penalty to positive-class errors to partially compensate for class imbalance

# %%
eps = 1e-8

pos_weight = (len(yq_train_small) - yq_train_small.sum()) / yq_train_small.sum()
pos_weight = float(pos_weight)

# %% [markdown]
# Instantiates loss function

# %%
def weighted_bce_loss(weights, X, y, pos_weight=1.0):
    losses = []
    for xi, yi in zip(X, y):
        p = quantum_model_train(xi, weights)
        p = pnp.clip(p, eps, 1 - eps)

        if yi == 1:
            loss = (-pos_weight * pnp.log(p + eps))
        else:
            loss = (-pnp.log(1 - p + eps))
        losses.append(loss)

    return pnp.mean(pnp.array(losses))

# %% [markdown]
# Initializes weights

# %%
np.random.seed(42)

weights = pnp.array(0.01 * np.random.randn(n_layers, n_qubits, 3), requires_grad=True)

# %% [markdown]
# Chooses optimizer and epochs (train time)

# %%
opt = qml.AdamOptimizer(stepsize=0.02)

epochs = 1
loss_history = []

# %% [markdown]
# Training loop

# %%
import time

start = time.time()

# %%
for epoch in range(epochs):
    weights = opt.step(lambda w: weighted_bce_loss(w, Xq_train_small, yq_train_small, pos_weight), weights)
    loss_val = weighted_bce_loss(weights, Xq_train_small, yq_train_small, pos_weight)
    loss_history.append(loss_val)
    if(epoch % 5 == 0):
        print(f"Epoch {epoch}, Loss: {loss_val:.4f}")

end = time.time()
print("Total training time:", end - start)
# Out:
# Epoch 0, Loss: 1.1990
# Total training time: 3.1766536235809326

# %% [markdown]
# Prints some additional results after training (beyond loss)

# %%
def predict_probs_train(X, weights):
    return np.array([float(quantum_model_train(x, weights)) for x in X])

def predict_probs_infer(X, weights):
    return np.array([float(quantum_model_infer(x, weights)) for x in X])

X_compare = Xq_test_angles[:5]
y_compare = yq_test[:5]

local_probs = predict_probs_train(X_compare, weights)
sv1_probs = predict_probs_infer(X_compare, weights)

print("True labels: ", y_compare)
print("Local probs: ", local_probs)
print("SV1 probs:   ", sv1_probs)

local_preds = (local_probs >= 0.5).astype(int)
sv1_preds = (sv1_probs >= 0.5).astype(int)

print("Local preds:", local_preds)
print("SV1 preds:  ", sv1_preds)
# Out:
# True labels:  [0 0 0 0 0]
# Local probs:  [0.63292537 0.44642766 0.44642766 0.44642766 0.44642766]
# SV1 probs:    [0.66 0.56 0.5  0.38 0.54]
# Local preds: [1 0 0 0 0]
# SV1 preds:   [1 1 1 0 1]

# %%
comparison_df = pd.DataFrame({
    "true_label": y_compare,
    "local_prob": local_probs,
    "sv1_prob": sv1_probs,
    "local_pred": local_preds,
    "sv1_pred": sv1_preds
})

comparison_df
# Out:
#    true_label  local_prob  sv1_prob  local_pred  sv1_pred
# 0           0    0.632925      0.62           1         1
# 1           0    0.446428      0.30           0         1
# 2           0    0.446428      0.46           0         1
# 3           0    0.446428      0.52           0         0
# 4           0    0.446428      0.42           0         1

# %% [markdown]
# Zip-level risk scores

# %%
test_probs_full_local = predict_probs_train(Xq_test_angles, weights)

results_df = test_df[id_cols + q_features + [target]].copy()
results_df['qml_risk_score'] = test_probs_full_local
results_df[['zip', 'Year', 'qml_risk_score']].head()

zip_scores = (
    results_df.groupby('zip', as_index=False)['qml_risk_score']
    .max()
    .sort_values('qml_risk_score', ascending=False)
)

zip_scores.head(10)
# Out:
#         zip  qml_risk_score
# 44  93308.0        0.833500
# 30  93226.0        0.833500
# 54  93453.0        0.833500
# 42  93287.0        0.833500
# 23  93066.0        0.833500
# 57  93465.0        0.833500
# 45  93401.0        0.783895
# 34  93249.0        0.783895
# 35  93251.0        0.783895
# 49  93428.0        0.783895
